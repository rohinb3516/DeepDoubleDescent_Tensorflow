# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl

from utils.train_utils import train_resnet18
from utils.visualizations import plot_loss_from_file, plot_loss_vs_epoch_from_file, load_results

# keeps tensorflow from using all available GPU memory when a model is initialized.
gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

print("Executed")
# Out:
# Executed

# %%
################################
# When we were doing 1000 epochs
################################

data_set = 'cifar10'
#Assigned: 13-16, 20, 48-56
resnet_widths_rohin = [i for i in range(13,17)]+[20]+[i for i in range(48,57)]+[64]

print("\nTraining ResNet on CIFAR-10 with 0 Label Noise\n")

label_noise = 0

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=resnet_widths_rohin,
    label_noise_as_int=label_noise,
    n_epochs=1000
)

print("\nTraining ResNet on CIFAR-10 with 0.1 Label Noise\n")

label_noise = 10

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=resnet_widths_rohin,
    label_noise_as_int=label_noise,
    n_epochs=1000
)

print("\nTraining ResNet on CIFAR-10 with 0.2 Label Noise\n")

label_noise = 20

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=resnet_widths_rohin,
    label_noise_as_int=label_noise,
    n_epochs=1000
)

print(metrics_fig1_rohin)
print("\nFINALLY!!!!!")
# Out:
# Training ResNet on CIFAR-10 with 0 Label Noise
#
# STARTING TRAINING: ResNet18_width_13, Label Noise: 0.0
# Epoch: 0000, Total Run Time: 00:00:13 - Loss: 2.0296e+00, Accuracy: 0.314, Test Loss: 1.7634e+00, Test Accuracy: 0.372
# Epoch: 0025, Total Run Time: 00:02:53 - Loss: 3.0191e-01, Accuracy: 0.899, Test Loss: 1.9273e+00, Test Accuracy: 0.532
# Epoch: 0050, Total Run Time: 00:05:32 - Loss: 1.5312e-03, Accuracy: 1.000, Test Loss: 3.0100e+00, Test Accuracy: 0.599
# Epoch: 0075, Total Run Time: 00:08:12 - Loss: 2.5352e-03, Accuracy: 1.000, Test Loss: 2.9120e+00, Test Accuracy: 0.604
# Epoch: 0100, Total Run Time: 00:10:51 - Loss: 2.0701e-03, Accuracy: 1.000, Test Loss: 3.1853e+00, Test Accuracy: 0.608
# Epoch: 0125, Total Run Time: 00:13:31 - Loss: 2.4611e-05, Accuracy: 1.000, Test Loss: 4.5061e+00, Test Accuracy: 0.604
# Epoch: 0150, Total Run Time: 00:16:10 - Loss: 5.5623e-05, Accuracy: 1.000, Test Loss: 4.0622e+00, Test Accuracy: 0.604
# ...

# %%
################################
# When we were doing 1000 epochs
# Contd.
################################

data_set = 'cifar10'
#Assigned: 13-16, 20, 48-56
resnet_widths_rohin = [i for i in range(13,17)]+[20]+[i for i in range(48,57)]+[64]

print("\nTraining ResNet on CIFAR-10 with 0 Label Noise\n")

label_noise = 0

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=[20]+[i for i in range(48,57)]+[64],
    label_noise_as_int=label_noise,
    n_epochs=1000
)

print("\nTraining ResNet on CIFAR-10 with 0.1 Label Noise\n")

label_noise = 10

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=resnet_widths_rohin,
    label_noise_as_int=label_noise,
    n_epochs=1000
)

print("\nTraining ResNet on CIFAR-10 with 0.2 Label Noise\n")

label_noise = 20

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=resnet_widths_rohin,
    label_noise_as_int=label_noise,
    n_epochs=1000
)

print(metrics_fig1_rohin)
print("\nFINALLY!!!!!")
# Out:
# Training ResNet on CIFAR-10 with 0 Label Noise
#
# STARTING TRAINING: ResNet18_width_20, Label Noise: 0.0
# Epoch: 0000, Total Run Time: 00:00:13 - Loss: 2.1614e+00, Accuracy: 0.334, Test Loss: 2.0599e+00, Test Accuracy: 0.311
# Epoch: 0025, Total Run Time: 00:03:24 - Loss: 9.6113e-02, Accuracy: 0.966, Test Loss: 3.5895e+00, Test Accuracy: 0.567
# Epoch: 0050, Total Run Time: 00:06:35 - Loss: 3.1024e-05, Accuracy: 1.000, Test Loss: 3.2693e+00, Test Accuracy: 0.656
# Epoch: 0075, Total Run Time: 00:09:47 - Loss: 1.5268e-07, Accuracy: 1.000, Test Loss: 4.5905e+00, Test Accuracy: 0.653
# Epoch: 0100, Total Run Time: 00:12:58 - Loss: 2.5926e-03, Accuracy: 1.000, Test Loss: 2.6176e+00, Test Accuracy: 0.655
# Epoch: 0125, Total Run Time: 00:16:11 - Loss: 1.0216e-05, Accuracy: 1.000, Test Loss: 3.6620e+00, Test Accuracy: 0.653
# Epoch: 0150, Total Run Time: 00:19:24 - Loss: 8.4660e-08, Accuracy: 1.000, Test Loss: 4.6716e+00, Test Accuracy: 0.652
# ...

# %%
###########################################
# When we momentarily agreeed on 350 epochs
###########################################

data_set = 'cifar10'
epochs = 350
#Assigned: 13-16, 20, 48-56
resnet_widths_rohin = [i for i in range(13,17)]+[
#Assigned: 13-16, 20, 48-56
resnet_widths_rohin = [i for i in range(13,17)]+[20,48,52,56,64]
"""
print("\nTraining ResNet on CIFAR-10 with 0 Label Noise\n")

label_noise = 0

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=[48,52,56,64],
    label_noise_as_int=label_noise,
    n_epochs=epochs
)
"""
print("\nTraining ResNet on CIFAR-10 with 0.1 Label Noise\n")

label_noise = 10

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=[52,56,64],
    label_noise_as_int=label_noise,
    n_epochs=epochs
)

print("\nTraining ResNet on CIFAR-10 with 0.2 Label Noise\n")

label_noise = 20

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=resnet_widths_rohin,
    label_noise_as_int=label_noise,
    n_epochs=epochs
)

print(metrics_fig1_rohin)
print("\nFINALLY!!!!!")
# Out:
# Training ResNet on CIFAR-10 with 0.1 Label Noise
#
# STARTING TRAINING: ResNet18_width_52, Label Noise: 0.1
# Epoch: 0000, Total Run Time: 00:00:26 - Loss: 2.4599e+00, Accuracy: 0.343, Test Loss: 2.1052e+00, Test Accuracy: 0.307
# Epoch: 0025, Total Run Time: 00:07:43 - Loss: 9.0247e-02, Accuracy: 0.974, Test Loss: 8.3511e+00, Test Accuracy: 0.297
# Epoch: 0050, Total Run Time: 00:15:01 - Loss: 2.2179e-05, Accuracy: 1.000, Test Loss: 2.2742e+00, Test Accuracy: 0.645
# Epoch: 0075, Total Run Time: 00:22:18 - Loss: 1.3884e-07, Accuracy: 1.000, Test Loss: 2.7336e+00, Test Accuracy: 0.651
# Epoch: 0100, Total Run Time: 00:29:35 - Loss: 1.8024e-09, Accuracy: 1.000, Test Loss: 2.9514e+00, Test Accuracy: 0.643
# Epoch: 0125, Total Run Time: 00:36:52 - Loss: 5.3120e-09, Accuracy: 1.000, Test Loss: 2.8661e+00, Test Accuracy: 0.642
# Epoch: 0150, Total Run Time: 00:44:10 - Loss: 1.5876e-08, Accuracy: 1.000, Test Loss: 3.0492e+00, Test Accuracy: 0.622
# ...

# %%
##################################
# When we decided doing 500 epochs
# Contd.
##################################

data_set = 'cifar10'
epochs = 500
#Assigned: 13-16, 20, 48-56
resnet_widths_rohin = [i for i in range(13,17)]+[20,48,52,56,64]
"""
print("\nTraining ResNet on CIFAR-10 with 0 Label Noise\n")

label_noise = 0

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=[48,52,56,64],
    label_noise_as_int=label_noise,
    n_epochs=epochs
)

print("\nTraining ResNet on CIFAR-10 with 0.1 Label Noise\n")

label_noise = 10

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=[52,56,64],
    label_noise_as_int=label_noise,
    n_epochs=epochs
)
"""
print("\nTraining ResNet on CIFAR-10 with 0.2 Label Noise\n")

label_noise = 20

metrics_noise0_rohin = list()
metrics_noise0_rohin = train_resnet18(
    data_set=data_set,
    resnet_widths=[20,48,52,56,64],
    label_noise_as_int=label_noise,
    n_epochs=epochs
)

print(metrics_fig1_rohin)
print("\nFINALLY!!!!!")
# Out:
# Training ResNet on CIFAR-10 with 0.2 Label Noise
#
# STARTING TRAINING: ResNet18_width_20, Label Noise: 0.2
# Epoch: 0000, Total Run Time: 00:00:15 - Loss: 2.1965e+00, Accuracy: 0.290, Test Loss: 2.9214e+00, Test Accuracy: 0.206
# Epoch: 0025, Total Run Time: 00:03:23 - Loss: 1.6166e-01, Accuracy: 0.947, Test Loss: 3.1546e+00, Test Accuracy: 0.460
# Epoch: 0050, Total Run Time: 00:06:30 - Loss: 3.9499e-05, Accuracy: 1.000, Test Loss: 5.1995e+00, Test Accuracy: 0.501
# Epoch: 0075, Total Run Time: 00:09:38 - Loss: 1.7146e-07, Accuracy: 1.000, Test Loss: 7.9022e+00, Test Accuracy: 0.486
# Epoch: 0100, Total Run Time: 00:12:46 - Loss: 4.1502e-05, Accuracy: 1.000, Test Loss: 5.3347e+00, Test Accuracy: 0.498
# Epoch: 0125, Total Run Time: 00:15:54 - Loss: 2.8909e-07, Accuracy: 1.000, Test Loss: 7.3921e+00, Test Accuracy: 0.497
# Epoch: 0150, Total Run Time: 00:19:02 - Loss: 1.3500e-04, Accuracy: 1.000, Test Loss: 4.9946e+00, Test Accuracy: 0.503
# ...

# %%
path = 'experimental_results_cifar10/resnet18_0pct_noise.pkl'
plot_loss_from_file(path)

# %%
import dill
dill.dump_session('ResNets_CIFAR10.db')
print("Executed")
# Out:
# Executed

# %%
# %load_ext autoreload
# %reload_ext autoreload

# Merging .pkl files from backups
import os
#os.chdir("..")

from utils.visualizations import plot_loss_from_file, plot_loss_vs_epoch_from_file, load_results
import pickle as pkl

# Data in dicts for epochs 500

noise0_dict1 = pkl.load(open(
    "experimental_results_cifar10/resnet18_0pct_noise_13-16_20_epochs_500.pkl",
    'rb'))
noise0_dict2 = pkl.load(open(
    "experimental_results_cifar10/resnet18_0pct_noise_48-56_64_epochs_500.pkl",
    'rb'))

noise0_dict = {**noise0_dict1, **noise0_dict2}


noise10_dict1 = pkl.load(open(
    "experimental_results_cifar10/resnet18_10pct_noise_13-16_20_48_epochs_500.pkl",
    'rb'))
noise10_dict2 = pkl.load(open(
    "experimental_results_cifar10/resnet18_10pct_noise_52_56_64_epochs_500.pkl",
    'rb'))

noise10_dict = {**noise10_dict1, **noise10_dict2}


noise20_dict1 = pkl.load(open(
    "experimental_results_cifar10/resnet18_20pct_noise_13-16_epochs_500.pkl",
    'rb'))
noise20_dict2 = pkl.load(open(
    "experimental_results_cifar10/resnet18_20pct_noise_20_48_epochs_500.pkl",
    'rb'))
noise20_dict3 = pkl.load(open(
    "experimental_results_cifar10/resnet18_20pct_noise_52_56_64_epochs_500.pkl",
    'rb'))

noise20_dict = {**noise20_dict1, **noise20_dict2, **noise20_dict3}

print("Results of widths 13-16, 20, 48, 52, 56 & 64 loaded and stored in dict.")

pkl.dump(noise0_dict, open("experimental_results_cifar10/resnet18_0pct_noise_rohin.pkl","wb"))
pkl.dump(noise10_dict, open("experimental_results_cifar10/resnet18_10pct_noise_rohin.pkl","wb"))
pkl.dump(noise20_dict, open("experimental_results_cifar10/resnet18_20pct_noise_rohin.pkl","wb"))

print("Stored for later use")

plot_loss_from_file("experimental_results_cifar10/resnet18_0pct_noise_rohin.pkl")
plot_loss_from_file("experimental_results_cifar10/resnet18_10pct_noise_rohin.pkl")
plot_loss_from_file("experimental_results_cifar10/resnet18_20pct_noise_rohin.pkl")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Results of widths 13-16, 20, 48, 52, 56 & 64 loaded and stored in dict.
# Stored for later use
